# %%
source("data_preperation.R")
source("modeling.R")
source("helper_functions.R")
source("player_track_graph.R")
library(ggplot2)
library(readr)
library(dplyr)
library(tidyverse)
library(gganimate)
library(sportyR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_47/1786041832.py in <cell line: 0>()
# ----> 1 source("data_preperation.R")
#       2 source("modeling.R")
#       3 source("helper_functions.R")
#       4 source("player_track_graph.R")
#       5 library(ggplot2)
#
# NameError: name 'source' is not defined
